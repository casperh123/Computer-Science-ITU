# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Neural Networks
# In the following exercises, you will use Neural Networks to solve the same task as in Assignment 1, gaze estimation.
#
# **Learning goals**
# After this week's exercises, you should be able to:
# - Experiment with the NN architecture to better reason about the impact of the different factors involved.
# - Evaluate the performance and reason about optimization strategies.
# - Evaluate the performance and reason about tuning techniques.
# - Evaluate the performance and discuss advantages and limitations.
